# %%
import numpy as np

# %%
data = np.loadtxt("linundata.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-680d1b451ffc> in <module>()
# ----> 1 data = np.loadtxt("linundata.csv")
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     983
#     984             # Convert each value according to its column and store
# --> 985             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     986             # Then pack it according to the dtype's nesting
#     987             items = pack_items(items, packing)
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/npyio.pyc in floatconv(x)
#     685         if b'0x' in x:
#     686             return float.fromhex(asstr(x))
# --> 687         return float(x)
#     688
#     689     typ = dtype.type
#
# ValueError: could not convert string to float: video

# %%
with open('linundata.csv', 'r') as f:
    data = [i for i in f.read().split()]
    print data
# Out:
# ['video', 'ID,Source,Title,start,watch10,complete', '226722476,Manulele,"Let\'s', 'Just', 'Go', 'Somewhere,', 'Billabong', 'Womens', '-', 'Autumn', '2015",135,132,36', '226722533,Manulele,"Benjamin', 'Sanchis', '-', 'Nazare,', 'Portugal.', "'NOUGH", 'SAID.",36,24,18', '226722595,Manulele,Taj', 'Burrow', '-', "Life's", 'Better', 'in', 'Boardshorts', '-', 'The', 'Slice', 'Boardshort,78,66,63', '226722667,Manulele,Billabong', '-', "Life's", 'Better', 'in', 'Boardshorts', '-', 'Dave', 'Rastovich,24,15,18', '238864522,Catch', 'Carri,https://www.youtube.com/channel/UCfLuMSIDmeWRYpuCQL0OJ6A,6,6,', '244117290,Wochit,Blue', 'Jays', 'Drop', 'First', 'MLB', 'Playoff', 'Game', 'in', '22', 'Years,7,4,1', '247306649,Wochit,Fetty', 'Wap', 'Is', 'Having', 'a', 'Baby!,1,1,1', '247313087,Wochit,Fetty', 'Wap', 'May', 'Not', 'Be', 'The', 'Father', 'OF', "Masika's", 'Baby,2,3,3', '247435000,Wochit,Fetty', 'Wap', 'Disses', 'Girlfriend', 'for', 'Pregnancy', 'Reveal,2,1,1', '248413156,WeSpeakFootball,Crazie
# ...
